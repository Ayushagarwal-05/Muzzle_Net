# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 4.2MB/s 1.5s1.5s<0.0s

# %%
model = YOLO("yolov8n.pt")

print("YOLO loaded.")
# Out:
# YOLO loaded.

# %%
from pathlib import Path

print("Train Images:",
      len(list(Path("../datasets/yolo_muzzle/images/train").glob("*.jpg"))))

print("Train Labels:",
      len(list(Path("../datasets/yolo_muzzle/labels/train").glob("*.txt"))))

print("Val Images:",
      len(list(Path("../datasets/yolo_muzzle/images/val").glob("*.jpg"))))

print("Val Labels:",
      len(list(Path("../datasets/yolo_muzzle/labels/val").glob("*.txt"))))
# Out:
# Train Images: 594
# Train Labels: 594
# Val Images: 149
# Val Labels: 149

# %%
sample_label = Path(
    "../datasets/yolo_muzzle/labels/train"
)

first_file = list(sample_label.glob("*.txt"))[0]

print(first_file)

with open(first_file) as f:
    print(f.read())
# Out:
# ..\datasets\yolo_muzzle\labels\train\A_0.txt
# 0 0.5 0.575 0.5 0.45

# %%
results = model.train(
    data="../datasets/yolo_muzzle/dataset.yaml",

    epochs=50,

    imgsz=640,

    batch=8,

    device=0,

    workers=4,

    project="../models",

    name="muzzle_detector"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.56 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.54  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../datasets/yolo_muzzle/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=muzzle_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../models, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 5.8MB/s 0.9s.9s<0.0ss
# AMP: checks passed
# train: Fast image access  (ping: 0.20.0 ms, read: 1049.492.6 MB/s, size: 2523.6 KB)
# train: Scanning D:\VS Code\Muzzle_Net\datasets\yolo_muzzle\labels\train... 594 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 594/594 1.3Kit/s 0.5s<0.1s
# train: New cache created: D:\VS Code\Muzzle_Net\datasets\yolo_muzzle\labels\train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.10.0 ms, read: 1772.685.4 MB/s, size: 2937.4 KB)
# val: Scanning D:\VS Code\Muzzle_Net\datasets\yolo_muzzle\labels\val... 149 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 149/149 1.1Kit/s 0.1s<0.1s
# val: New cache created: D:\VS Code\Muzzle_Net\datasets\yolo_muzzle\labels\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector\labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50       1.1G       1.95      2.597      2.049          2        640: 100% ━━━━━━━━━━━━ 75/75 5.0it/s 14.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 7.0it/s 1.4s.1s
#                    all        149        149      0.556      0.644      0.676       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.14G      1.442      1.761      1.519          2        640: 100% ━━━━━━━━━━━━ 75/75 5.1it/s 14.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.3it/s 1.2s.1s
#                    all        149        149      0.635      0.725       0.69      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.14G      1.419      1.571      1.474          2        640: 100% ━━━━━━━━━━━━ 75/75 5.2it/s 14.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.8it/s 1.1s.1s
#                    all        149        149      0.907      0.915      0.958      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.14G      1.331      1.367      1.414          2        640: 100% ━━━━━━━━━━━━ 75/75 5.3it/s 14.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8
0.97
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.14G     0.5956     0.5056      1.007          2        640: 100% ━━━━━━━━━━━━ 75/75 4.7it/s 15.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.2it/s 1.2s.1s
#                    all        149        149          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.14G     0.5806     0.4982     0.9947          2        640: 100% ━━━━━━━━━━━━ 75/75 4.9it/s 15.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 7.7it/s 1.3s.2s
#                    all        149        149          1          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.14G      0.596     0.5167      1.013          2        640: 100% ━━━━━━━━━━━━ 75/75 4.8it/s 15.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 7.6it/s 1.3s.2s
#                    all        149        149          1          1      0.995      0.984
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.14G     0.5079     0.4271      1.043          2        640: 100% ━━━━━━━━━━━━ 75/75 4.8it/s 15.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 9.3it/s 1.1s.1s
#                    all        149        149          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.14G     0.5022     0.3731      1.055          2        640: 100% ━━━━━━━━━━━━ 75/75 5.1it/s 14.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.2it/s 1.2s.2s
#                    all        149        149          1          1      0.995      0.979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.14G     0.5276     0.3588      1.059          2        640: 100% ━━━━━━━━━━━━ 75/75 4.8it/s 15.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.1it/s 1.2s.2s
#                    all        149        149          1          1      0.995      0.965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.14G     0.4792     0.3392      1.037          2        640: 100% ━━━━━━━━━━━━ 75/75 4.9it/s 15.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.2it/s 1.2s.1s
#                    all        149        149          1          1      0.995      0.968
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.14G     0.5163     0.3652      1.083          2        640: 100% ━━━━━━━━━━━━ 75/75 5.0it/s 15.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.7it/s 1.1s.1s
#                    all        149        149          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.14G     0.4594     0.3192       1.03          2        640: 100% ━━━━━━━━━━━━ 75/75 4.8it/s 15.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.5it/s 1.2s.1s
#                    all        149        149          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.14G     0.4477     0.3136      1.025          2        640: 100% ━━━━━━━━━━━━ 75/75 4.8it/s 15.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.0it/s 1.2s.2s
#                    all        149        149          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.14G     0.4165     0.3024      1.002          2        640: 100% ━━━━━━━━━━━━ 75/75 3.8it/s 19.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.5it/s 6.7s.8ss
#                    all        149        149          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.14G     0.4153     0.2919     0.9996          2        640: 100% ━━━━━━━━━━━━ 75/75 5.7it/s 13.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 9.3it/s 1.1s.1s
#                    all        149        149          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.14G      0.373     0.2819     0.9687          2        640: 100% ━━━━━━━━━━━━ 75/75 5.1it/s 14.8s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 8.8it/s 1.1s.1s
#                    all        149        149          1          1      0.995      0.995
#
# 50 epochs completed in 0.242 hours.
# Optimizer stripped from D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector\weights\last.pt, 6.2MB
# Optimizer stripped from D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector\weights\best.pt, 6.2MB
#
# Validating D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector\weights\best.pt...
# Ultralytics 8.4.54  Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 5.8it/s 1.7s.2s
#                    all        149        149          1          1      0.995      0.995
# Speed: 0.3ms preprocess, 1.9ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to D:\VS Code\Muzzle_Net\notebooks\runs\models\muzzle_detector
